# %% [markdown]
# # Trabalho Final - Algebra Linear

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
import seaborn as sns

# %% [markdown]
# ## Inicialmente, importando a base de dados e fazendo pequenas análises.

# %%
data = pd.read_csv('../trabalho_final/data2.csv')
data.sample(5)
# Out:
#          id gender   age  hypertension  heart_disease ever_married  \
# 1891  12376   Male  63.0             0              0          Yes
# 3296  64742   Male  48.0             0              0           No
# 2229  64895   Male  54.0             1              0          Yes
# 662   23551   Male  28.0             0              0          Yes
# 2467   7892   Male  78.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 1891       Govt_job          Urban              95.16  37.8  formerly smoked
# 3296  Self-employed          Rural              64.18  32.1     never smoked
# 2229  Self-employed          Rural             104.42  37.6           smokes
# 662         Private          Urban              87.43  55.7          Unknown
# 2467        Private          Urban              74.70  28.8  formerly smoked
#
#       stroke
# 1891       0
# 3296       0
# 2229       0
# 662        0
# 2467       0

# %%
sns.countplot(x='stroke',data=data,palette='hls')
plt.show()

# %% [markdown]
# ## Criando as funções para a Regressão Logística

# %% [markdown]
# ### Função sigmóide (logit)

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %% [markdown]
# ### Função de custo

# %%
def compute_cost(X, y, theta):
    m = len(y)
    h = sigmoid(X @ theta)
    epsilon = 0.00001
    cost = (1/m)*(((-y).T @ np.log(h + epsilon))-((1-y).T @ np.log(1-h + epsilon)))
    return cost

# %% [markdown]
# ### Gradiente descendente

# %%
def gradient_descent(X, y, params, learning_rate, iterations):
    m = len(y)
    cost_history = np.zeros((iterations,1))

    for i in range(iterations):
        params = params - (learning_rate/m) * (X.T @ (sigmoid(X @ params) - y)) 
        cost_history[i] = compute_cost(X, y, params)

    return (cost_history, params)

# %% [markdown]
# ### Função de predição
#     Maior que 0.5 é arredondada p/ 1, menor p/ 0.

# %%
def predict(X, params):
    return np.round(sigmoid(X @ params))

# %% [markdown]
# ## Gera dados fake pra testar se tudo beleza
# curiosamente, estava sim

# %%
X, y = make_classification(n_samples=500, n_features=2, n_redundant=0, n_informative=1,
                             n_clusters_per_class=1, random_state=14)

y = y[:,np.newaxis]

data = pd.DataFrame(np.hstack((y, X)))

data = data.rename(columns={0:'col0', 1:'col1', 2:'col2'})

data
# Out:
#      col0      col1      col2
# 0     1.0  0.943625 -0.679783
# 1     0.0 -0.868018 -0.253922
# 2     0.0 -1.767471 -0.999924
# 3     1.0  0.572276  0.394579
# 4     0.0 -1.436026 -1.307645
# ..    ...       ...       ...
# 495   0.0 -1.982349  1.843219
# 496   1.0  0.382819 -1.301479
# 497   1.0  0.975822 -0.991358
# 498   1.0  0.960052  0.583745
# 499   0.0 -1.522811  0.339353
#
# [500 rows x 3 columns]

# %% [markdown]
# ## Tratando NaNs e selecionando as colunas
#     papel importante a ser feito

# %%
cols = {
    'y' : 'stroke',
    'x_1' : 'avg_glucose_level',
    'x_2' : 'bmi'
}

# reduz a base para as colunas que serão utilizadas
data = data[[cols['y'], cols['x_1'], cols['x_2'] ]]

# remove os dados nulos
data = data.dropna()

data
# Out:
#       stroke  avg_glucose_level   bmi
# 0          1             228.69  36.6
# 2          1             105.92  32.5
# 3          1             171.23  34.4
# 4          1             174.12  24.0
# 5          1             186.21  29.0
# ...      ...                ...   ...
# 5104       0             103.08  18.6
# 5106       0             125.20  40.0
# 5107       0              82.99  30.6
# 5108       0             166.29  25.6
# 5109       0              85.28  26.2
#
# [4909 rows x 3 columns]

# %% [markdown]
# ## Transformando os dados
#     pd.core.series.Series em np.ndarray

# %%
y = data[cols['y']].to_numpy(dtype ='int')
y = y[:,np.newaxis] #transforma y em um vetor coluna

X_1 = data[cols['x_1']].to_numpy(dtype ='float')
X_1 = np.vstack((X_1)) #transforma x_1 em vec coluna

X_2 = data[cols['x_2']].to_numpy(dtype ='float')
X_2 = np.vstack((X_2)) #transforma x_2 em vec coluna

X = np.hstack((X_1,X_2))
X # final result
# Out:
# array([[228.69,  36.6 ],
#        [105.92,  32.5 ],
#        [171.23,  34.4 ],
#        ...,
#        [ 82.99,  30.6 ],
#        [166.29,  25.6 ],
#        [ 85.28,  26.2 ]])

# %%
sns.scatterplot(x = X[:,0], y = X[:,1], hue = y.reshape(-1));

# legendas
plt.xlabel(cols['x_1'].replace("_", " ").title())
plt.ylabel(cols['x_2'].replace("_", " ").title())
# Out:
# Text(0, 0.5, 'Bmi')

# %%
m = len(y)

X_new = np.hstack((np.ones((m,1)),X))
n = np.size(X_new,1)
params = np.zeros((n,1))

iterations = 1500
learning_rate = 0.03

initial_cost = compute_cost(X_new, y, params)
print("Initial Cost is: {} \n".format(initial_cost))

(cost_history, params_optimal) = gradient_descent(X_new, y, params, learning_rate, iterations)

y_pred = predict(X_new, params_optimal)
score = float(sum(y_pred == y))/ float(len(y))

print(params_optimal)

plt.figure()
sns.set_style('white')
plt.plot(range(len(cost_history)), cost_history, 'r')
plt.title("Convergence Graph of Cost Function")
plt.xlabel("Number of Iterations")
plt.ylabel("Cost")
plt.show()
# Out:
# Initial Cost is: [[0.69312718]]
# <ipython-input-4-b683d5dd8fa4>:2: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-x))
# [[-0.24707086]
#  [ 0.01599977]
#  [-0.37805807]]

# %%
y_pred = predict(X_new, params_optimal)
score = float(sum(y_pred == y))/ float(len(y))

print(score)
# Out:
# 0.966

# %%
slope = -(params_optimal[1] / params_optimal[2])
intercept = -(params_optimal[0] / params_optimal[2])

sns.set_style('white')
sns.scatterplot(x = X_new[:,1], y= X_new[:,2], hue=y.reshape(-1));

ax = plt.gca()
ax.autoscale(False)
x_vals = np.array(ax.get_xlim())
y_vals = intercept + (slope * x_vals)
plt.plot(x_vals, y_vals, c="k");

# legendas
plt.xlabel(cols['x_1'].replace("_", " ").title())
plt.ylabel(cols['x_2'].replace("_", " ").title())
# Out:
# Text(0, 0.5, 'Col2')
