# %% [markdown]
# # Trabalho Final - Algebra Linear

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
import seaborn as sns

# %% [markdown]
# ## Inicialmente, importando a base de dados e fazendo pequenas análises.

# %%
data = pd.read_csv('../trabalho_final/data2.csv')
data.sample(5)
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 1553  54858    Male  66.0             0              0          Yes
# 2163  47582    Male   3.0             0              0           No
# 1755  67144  Female  65.0             0              0          Yes
# 3913   6172  Female  79.0             0              0          Yes
# 1733  16028  Female  45.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi smoking_status  \
# 1553       Govt_job          Rural             218.54  38.9         smokes
# 2163       children          Urban              59.05  16.6        Unknown
# 1755  Self-employed          Urban              82.21  26.2        Unknown
# 3913        Private          Rural             208.05   NaN         smokes
# 1733        Private          Rural              77.19  37.2         smokes
#
#       stroke
# 1553       0
# 2163       0
# 1755       0
# 3913       0
# 1733       0

# %%
sns.countplot(x='stroke',data=data,palette='hls')
plt.show()

# %% [markdown]
# ## Criando as funções para a Regressão Logística

# %% [markdown]
# ### Função sigmóide (logit)

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %% [markdown]
# ### Função de custo

# %%
def compute_cost(X, y, theta):
    m = len(y)
    h = sigmoid(X @ theta)
    epsilon = 1e-5
    cost = (1/m)*(((-y).T @ np.log(h + epsilon))-((1-y).T @ np.log(1-h + epsilon)))
    return cost

# %% [markdown]
# ### Gradiente descendente

# %%
def gradient_descent(X, y, params, learning_rate, iterations):
    m = len(y)
    cost_history = np.zeros((iterations,1))

    for i in range(iterations):
        params = params - (learning_rate/m) * (X.T @ (sigmoid(X @ params) - y)) 
        cost_history[i] = compute_cost(X, y, params)

    return (cost_history, params)

# %% [markdown]
# ### Função de predição
#     Maior que 0.5 é arredondada p/ 1, menor p/ 0.

# %%
def predict(X, params):
    return np.round(sigmoid(X @ params))

# %% [markdown]
# ## Tratando NaNs
#     papel importante a ser feito

# %%
data = data.dropna()

# %% [markdown]
# ## Transformando os dados
#     pd.core.series.Series em np.ndarray

# %%
y = data['stroke'].to_numpy(dtype ='int')
y = y[:,np.newaxis] #transforma y em um vetor coluna
X_1 = data['avg_glucose_level'].to_numpy(dtype ='float')
X_1 = np.vstack((X_1))

X_2 = data['bmi'].to_numpy(dtype ='float')
X_2 = np.vstack((X_2))
X = np.hstack((X_1,X_2))

# %%
sns.set_style('white')
sns.scatterplot(X[:,0],X[:,1],hue=y.reshape(-1),palette='hls');
plt.xlabel("avg_glucose_level")
plt.ylabel("bmi")
# Out:
# C:\Users\Conda\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'bmi')

# %%
m = len(y)

X_new = np.hstack((np.ones((m,1)),X))
n = np.size(X_new,1)
params = np.zeros((n,1))

iterations = 1500
learning_rate = 0.03

initial_cost = compute_cost(X_new, y, params)
print("Initial Cost is: {} \n".format(initial_cost))

(cost_history, params_optimal) = gradient_descent(X_new, y, params, learning_rate, iterations)

y_pred = predict(X_new, params_optimal)
score = float(sum(y_pred == y))/ float(len(y))

print(params_optimal)
# Out:
# Initial Cost is: [[0.69312718]]
# <ipython-input-4-b683d5dd8fa4>:2: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-x))
# [[-0.24707086]
#  [ 0.01599977]
#  [-0.37805807]]

# %%
y_pred = predict(X_new, params_optimal)
score = float(sum(y_pred == y))/ float(len(y))

print(score)
# Out:
# 0.9574251375025463

# %%
slope = -(params_optimal[1] / params_optimal[2])
intercept = -(params_optimal[0] / params_optimal[2])

sns.set_style('white')
sns.scatterplot(X_new[:,1],X_new[:,2],hue=y.reshape(-1));

ax = plt.gca()
ax.autoscale(False)
x_vals = np.array(ax.get_xlim())
y_vals = intercept + (slope * x_vals)
plt.plot(x_vals, y_vals, c="k");
# Out:
# C:\Users\Conda\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
