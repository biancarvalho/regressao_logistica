# %% [markdown]
# # Trabalho Final - Algebra Linear

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
import seaborn as sns

# %% [markdown]
# ## Inicialmente, importando a base de dados e fazendo pequenas análises.
#     Link para o dataset: [Kaggle: Customer Personality Analysis](https://www.kaggle.com/imakash3011/customer-personality-analysis)

# %%
data = pd.read_csv('../trabalho_final/data3.csv')
data.sample(5)
# Out:
#          ID  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 62     1012        1952  Graduation         Single  61823.0        0
# 1023   4550        1966      Master       Together  33564.0        0
# 91     9235        1957  Graduation         Single      NaN        1
# 245    7411        1964         PhD        Married  31686.0        1
# 758   10470        1979      Master        Married  40662.0        1
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  NumWebVisitsMonth  \
# 62           1  18-02-2013       26       523  ...                  7
# 1023         1  24-06-2014       51        61  ...                  5
# 91           1  27-05-2014       45         7  ...                  7
# 245          1  05-06-2014       31        11  ...                  6
# 758          0  15-03-2013        0        40  ...                  4
#
#       AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  \
# 62               0             0             0             0             0
# 1023             0             0             0             0             0
# 91               0             0             0             0             0
# 245              0             0             0             0             0
# 758              0             0             0             0             0
#
#       Complain  Z_CostContact  Z_Revenue  Response
# 62           0              3         11         0
# 1023         0              3         11         0
# 91           0              3         11         0
# 245          0              3         11         0
# 758          0              3         11         0
#
# [5 rows x 29 columns]

# %%
sns.countplot(x='AcceptedCmp5',data=data,palette='hls') #1 if customer accepted the offer in the 5th campaign, 0 otherwise
plt.show()

# %% [markdown]
# ## Criando as funções para a Regressão Logística

# %% [markdown]
# ### Função sigmóide (logit)

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %% [markdown]
# ### Função de custo

# %%
def compute_cost(X, y, theta):
    m = len(y)
    h = sigmoid(X @ theta)
    epsilon = 1e-5
    cost = (1/m)*(((-y).T @ np.log(h + epsilon))-((1-y).T @ np.log(1-h + epsilon)))
    return cost

# %% [markdown]
# ### Gradiente descendente

# %%
def gradient_descent(X, y, params, learning_rate, iterations):
    m = len(y)
    cost_history = np.zeros((iterations,1))

    for i in range(iterations):
        params = params - (learning_rate/m) * (X.T @ (sigmoid(X @ params) - y)) 
        cost_history[i] = compute_cost(X, y, params)

    return (cost_history, params)

# %% [markdown]
# ### Função de predição
#     Maior que 0.5 é arredondada p/ 1, menor p/ 0.

# %%
def predict(X, params):
    return np.round(sigmoid(X @ params))

# %% [markdown]
# ## Tratando NaNs
#     papel importante a ser feito

# %%
data = data.dropna()

# %% [markdown]
# ## Transformando os dados
#     pd.core.series.Series em np.ndarray

# %%
y = data['AcceptedCmp5'].to_numpy(dtype ='int')
y = y[:,np.newaxis] #transforma y em um vetor coluna

X_1 = data['MntWines'].to_numpy(dtype ='float')
X_1 = np.vstack((X_1))

X_2 = data['MntGoldProds'].to_numpy(dtype ='float')
X_2 = np.vstack((X_2))

X = np.hstack((X_1,X_2))

# %%
sns.set_style('white')
sns.scatterplot(X[:,0],X[:,1],hue=y.reshape(-1),palette='hls');
plt.xlabel("avg_glucose_level")
plt.ylabel("bmi")
# Out:
# C:\Users\Bia\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'bmi')

# %%
m = len(y)

X_new = np.hstack((np.ones((m,1)),X))
n = np.size(X_new,1)
params = np.zeros((n,1))

iterations = 1500
learning_rate = 0.03

initial_cost = compute_cost(X_new, y, params)
print("Initial Cost is: {} \n".format(initial_cost))

(cost_history, params_optimal) = gradient_descent(X_new, y, params, learning_rate, iterations)

y_pred = predict(X_new, params_optimal)
score = float(sum(y_pred == y))/ float(len(y))

print(params_optimal)
# Out:
# Initial Cost is: [[0.69312718]]
# <ipython-input-4-b683d5dd8fa4>:2: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-x))
# [[-3.35580562]
#  [ 1.31633753]
#  [-2.21953902]]

# %%
y_pred = predict(X_new, params_optimal)
score = float(sum(y_pred == y))/ float(len(y))

print(score)
# Out:
# 0.3109205776173285

# %%
slope = -(params_optimal[1] / params_optimal[2])
intercept = -(params_optimal[0] / params_optimal[2])

sns.set_style('white')
sns.scatterplot(X_new[:,1],X_new[:,2],hue=y.reshape(-1),palette='hls');

ax = plt.gca()
ax.autoscale(False)
x_vals = np.array(ax.get_xlim())
y_vals = intercept + (slope * x_vals)
plt.plot(x_vals, y_vals, c="k");
# Out:
# C:\Users\Bia\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
